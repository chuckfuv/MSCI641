# %%
import sys
import os
import numpy as np
from numpy import array
from numpy import asarray
from tensorflow.keras.utils import to_categorical
import pandas as pd
import tensorflow as tf
#from gensim.models import Word2Vec
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, BatchNormalization, Activation, Bidirectional, Flatten
from tensorflow.keras.preprocessing.text import text_to_word_sequence, Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import callbacks, regularizers
from utils.dataset import DataSet
from utils.generate_test_splits import train_vali_split, get_stances_for_folds
from utils.score import report_score, LABELS, score_submission
from tensorflow.keras.utils import plot_model
from utils.system import parse_params, check_version
import nltk

import string

# %%
LSTM_DIM = 300
EMBEDDING_DIM = 300

# %%
#Load the training dataset and generate folds
d = DataSet()
training, hold_out = train_vali_split(d)
training_stances, hold_out_stances = get_stances_for_folds(d,training,hold_out)
# Load the competition dataset
competition_dataset = DataSet("competition_test")
#X_competition, y_competition = generate_features(competition_dataset.stances, competition_dataset, "competition")

Xs = dict()
ys = dict()
# Out:
# Reading dataset
# Total stances: 49972
# Total bodies: 1683
# Reading dataset
# Total stances: 25413
# Total bodies: 904

# %%
def prepareData(dataset, stances):
    headline = []
    body = []
    stanceFinal = []
    for stance in stances:
        headline.append(stance['Headline'])
        body.append(dataset.articles[stance['Body ID']])
        stanceFinal.append(stance['Stance'])
    return headline, body, stanceFinal

# %%
train_headline, train_body, train_stanceFinal = prepareData(d, training_stances)
hold_out_headline, hold_out_body, hold_out_stanceFinal = prepareData(d, hold_out_stances)

# %%
competition_headline, competition_body, competition_stanceFinal = prepareData(competition_dataset, competition_dataset.stances)

# %%
def stance_to_onehot(stance):
    li = []
    LABELS = ['agree', 'disagree', 'discuss', 'unrelated']
    for i in stance:
        if i == LABELS[0]:
            li.append([1,0,0,0])
        elif i == LABELS[1]:
            li.append([0,1,0,0])
        elif i == LABELS[2]:
            li.append([0,0,1,0])
        elif i == LABELS[3]:
            li.append([0,0,0,1])
    return np.array(li)

# %%
competition_stance_onehot = stance_to_onehot(competition_stanceFinal)
train_stance_onehot = stance_to_onehot(train_stanceFinal)
hold_out_stance_onehot = stance_to_onehot(hold_out_stanceFinal)

# %%
def get_tokens(text):
    lowers = text.lower()

    remove_punctuation_map = dict((ord(char), None) for char in string.punctuation)
    no_punctuation = lowers.translate(remove_punctuation_map)
    tokens = nltk.word_tokenize(no_punctuation)

    return tokens
train_headline = [get_tokens(text) for text in train_headline]
hold_out_headline = [get_tokens(text) for text in hold_out_headline]
train_body = [get_tokens(text) for text in train_body]
hold_out_body = [get_tokens(text) for text in hold_out_body]
competition_headline = [get_tokens(text) for text in competition_headline]
competition_body = [get_tokens(text) for text in competition_body]

# %%
tokenizer = Tokenizer()

# %%
corpus = train_headline+train_body+hold_out_headline+hold_out_body+competition_headline+competition_body

# %%
tokenizer.fit_on_texts([' '.join(seq) for seq in corpus])

# %%
print("Number of words in vocabulary:", len(tokenizer.word_index))
# Out:
# Number of words in vocabulary: 34118

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
train_headline = tokenizer.texts_to_sequences(train_headline)
train_body = tokenizer.texts_to_sequences(train_body)
hold_out_headline = tokenizer.texts_to_sequences(hold_out_headline)
hold_out_body = tokenizer.texts_to_sequences(hold_out_body)
competition_headline = tokenizer.texts_to_sequences(competition_headline)
competition_body = tokenizer.texts_to_sequences(competition_body)

# %%
MAX_HEADLINE_LENGTH = int(np.percentile([len(doc) for doc in train_headline+hold_out_headline], 90))
print('90th Percentile headline Length:', MAX_HEADLINE_LENGTH)
MAX_BODY_LENGTH = int(np.mean([len(doc) for doc in train_body+hold_out_body]))
print('90th Percentile body Length:', MAX_BODY_LENGTH)
MAX_BODY_TRUNC = 50
# Out:
# 90th Percentile headline Length: 16
# 90th Percentile body Length: 378

# %%
train_headline = pad_sequences(train_headline, maxlen=MAX_HEADLINE_LENGTH, padding='post', truncating='post')
hold_out_headline = pad_sequences(hold_out_headline, maxlen=MAX_HEADLINE_LENGTH, padding='post', truncating='post')
train_first_body = pad_sequences(train_body, maxlen=MAX_BODY_TRUNC, padding='post', truncating='post')
train_last_body = pad_sequences(train_body, maxlen=MAX_BODY_TRUNC, padding='pre', truncating='pre')
hold_out_first_body = pad_sequences(hold_out_body, maxlen=MAX_BODY_TRUNC, padding='post', truncating='post')
hold_out_last_body = pad_sequences(hold_out_body, maxlen=MAX_BODY_TRUNC, padding='pre', truncating='pre')
competition_headline = pad_sequences(competition_headline, maxlen=MAX_HEADLINE_LENGTH, padding='post', truncating='post')
competition_first_body = pad_sequences(competition_body, maxlen=MAX_BODY_TRUNC, padding='post', truncating='post')
competition_last_body = pad_sequences(competition_body, maxlen=MAX_BODY_TRUNC, padding='pre', truncating='pre')

# %%
# load the whole embedding into memory
embeddings_index = dict()
f = open('glove.42B.300d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 1917494 word vectors.

# %%
# create a weight matrix for words in training docs
embedding_matrix = np.zeros((vocab_size, 300))
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
    else:
        print("not found words: ", word)
del embeddings_index
# Out:
# not found words:  sotloff
# not found words:  albaghdadi
# not found words:  emwazi
# not found words:  kobani
# not found words:  tridevil
# not found words:  jongun
# not found words:  usled
# not found words:  zehafbibeau
# not found words:  vorozhbitsyn
# not found words:  chibok
# not found words:  alnusra
# not found words:  aldulaimi
# not found words:  crabzilla
# not found words:  fredou
# not found words:  21yearold
# not found words:  clarkemurphy
# not found words:  sergeantatarms
# not found words:  hairgate
# not found words:  sotloffs
# not found words:  kadalim
# not found words:  31yearold
# not found words:  yojong
# not found words:  jongil
# not found words:  alanbar
# not found words:  lobison
# not found words:  tridevils
# not found words:  albaghdadis
# not found words:  abdelmajed
# not found words:  helric
# not found words:  adsupported
# not found words:  17yearold
# not found words:  pumpkinspice
# not found words:  canadianisraeli
# not found words:  albritani
# not found words:  dejeus
# not found words:  badeh
# not found words:  alhakim
# not found words:  alzameli
# not found words:  twinztv
# not found words:  britishborn
# not found words:  kassig
# not found words:  omeri
# not found words:  ■
# not found words:  10yearold
# not found words:  40yearold
# not found words:  fiveday
# not found words:  bringbackourgirls
# not found words:  ilsung
# not found words:  tawils
# not found words:  knightscope
# not found words:  britainbased
# not found words:  babici
# not found words:  alassad
# not found words:  19yearold
# not found words:  motherjones​com
# not found words:  7036144309
# not found words:  ontherecordusmcmil
# not found words:  exbear
# not found words:  sevenfigure
# not found words:  generation…
# not found words:  kong—thousands
# not found words:  kimjongun
# not found words:  songthaeks
# not found words:  jangs
# not found words:  bunburys
# not found words:  pinthin
# not found words:  nature…have
# not found words:  ladenorchestrated
# not found words:  5by7inch
# not found words:  stashthe
# not found words:  reexcavate
# not found words:  wcvbscreen
# not found words:  cityarea
# not found words:  vgotorious
# not found words:  scrubbedclean
# not found words:  vgproductions
# not found words:  andreysmygovs
# not found words:  regrammed
# not found words:  ��
# not found words:  bugattifamilyimsorry
# not found words:  …do
# not found words:  proqaddafi
# not found words:  mazaresharif
# not found words:  aldumani
# not found words:  cohel
# not found words:  lytrolike
# not found words:  myungchul
# not found words:  a—
# not found words:  kentonline
# not found words:  whitstablecrabzilla
# not found words:  ameriyat
# not found words:  ⟨⟩
# not found words:  wilgenburg
# not found words:  kiziltan
# not found words:  europeradio
# not found words:  derfuss
# not found words:  18carat
# not found words:  gaybasher
# not found words:  helm–kim
# not found words:  jong–according
# not found words:  rungna
# not found words:  photokorean
# not found words:  recentlydiscovered
# not found words:  decadeold
# not found words:  matchheadsized
# not found words:  داعش
# not found words:  streetartist
# not found words:  operatingroom
# not found words:  blooddriven
# not found words:  15member
# not found words:  countercurrentnewscom
# not found words:  20150130
# not found words:  94033
# not found words:  spaghettios…we
# not found words:  cybersleuthing
# not found words:  factchecked
# not found words:  lagosbenin
# not found words:  alqami
# not found words:  qiangs
# not found words:  ­accent
# not found words:  ­islamic
# not found words:  amazonexclusive
# not found words:  locationcustomer
# not found words:  minimansion
# not found words:  nbc–not
# not found words:  cannabisinfused
# not found words:  sirsabased
# not found words:  20141023
# not found words:  uneaten—and
# not found words:  burgerbuying
# not found words:  moldfree
# not found words:  mcjordan
# not found words:  42x36x10
# not found words:  oscarwinner
# not found words:  peshmergas
# not found words:  adamgoldmanwp
# not found words:  largescreen
# not found words:  phasedetection
# not found words:  httpafricacheckorgreportsstoryofgutsybraveheartsfightingbokoharamisahoaxsthashksrlgtqo7zmluayldpuf
# not found words:  process—known
# not found words:  —before
# not found words:  upicom
# not found words:  £638000
# not found words:  connectfacebooknetenusalljsxfbml1
# not found words:  is…
# not found words:  outofbody
# not found words:  alzamili
# not found words:  windforecast
# not found words:  aytozinapa
# not found words:  camerinosan
# not found words:  ayotzinapa
# not found words:  storewithinastore
# not found words:  onemonth
# not found words:  idcorners
# not found words:  image—that
# not found words:  business—a
# not found words:  business—to
# not found words:  imagedoctoring
# not found words:  jarvisshean
# not found words:  4089202706
# not found words:  twittercomdanahull
# not found words:  qbical
# not found words:  tutoring…
# not found words:  9newscom
# not found words:  objecting…
# not found words:  midaugust
# not found words:  askfm
# not found words:  shaffa
# not found words:  lugtenborg
# not found words:  mogadishus
# not found words:  عبدالله
# not found words:  fbithe
# not found words:  foely
# not found words:  dcbased
# not found words:  ruwayda
# not found words:  irshaid
# not found words:  hwangs
# not found words:  nontechy
# not found words:  preyear2007
# not found words:  watch…thats
# not found words:  9to5community
# not found words:  emilydreyfuss
# not found words:  triplebreasted
# not found words:  sittingonthefloor
# not found words:  yearoveryear
# not found words:  imagesharing
# not found words:  occupycentral
# not found words:  jinpings
# not found words:  cryeleike
# not found words:  almansouri
# not found words:  bodylength
# not found words:  nasdaqbbry
# not found words:  tsebb
# not found words:  aens
# not found words:  stomachspider
# not found words:  iraqinewscom
# not found words:  asyetunidentified
# not found words:  experience…and
# not found words:  chchcheck
# not found words:  americanled
# not found words:  greyhaired
# not found words:  michaelplattsunmediaca​
# not found words:  gtastyle
# not found words:  suicidebombers
# not found words:  hostagetakers
# not found words:  seeback
# not found words:  pyongyangs
# not found words:  chassismany
# not found words:  crediblewhile
# not found words:  themichaelreportcom
# not found words:  albaghdad
# not found words:  airstrikeisis
# not found words:  airstrikesisis
# not found words:  eidiraqi
# not found words:  alkhurafa
# not found words:  amiriyat
# not found words:  alfallujah
# not found words:  km²
# ...
# not found words:  httprtcomusagmoglutensensitivitytrigger343
# not found words:  httpresponsibletechnologyorgmediaimagescontentpressreleasegluten1125pdf
# not found words:  httpwwwsciencedirectcomsciencearticlepiis0278691512005637
# not found words:  httpwwwncbinlmnihgovpubmed23756170
# not found words:  httpearthopensourceorgfilespdfsroundupandbirthdefectsroundupandbirthdefectsv5pdf
# not found words:  httppubsacsorgdoiabs101021tx1001749
# not found words:  httpwwwmdpicom109943001541416
# not found words:  httpomicsonlineorgopenaccessdetectionofglyphosateresiduesinanimalsandhumans216105251000210pdf
# not found words:  httpwwworganicsystemsorgjournal818106pdf
# not found words:  httpstaticabocacomwwwabocacomfilesattachnewsriskassessmentofgeneticallymodifiedcropsfornutritionpdf
# not found words:  200421299–324
# not found words:  200220969–969
# not found words:  httpwwwncbinlmnihgovpubmed19146501
# not found words:  this—
# not found words:  collectiveevolutioncom—outlines
# not found words:  experimentassay
# not found words:  biofortifiedorg
# not found words:  buds…
# not found words:  nonhormone
# not found words:  dish—what
# not found words:  tissueculture
# not found words:  micerats
# not found words:  s—meaning
# not found words:  gmotesting
# not found words:  naturecom
# not found words:  organicconventional
# not found words:  nongmo
# not found words:  nongmfed
# not found words:  gmfeed
# not found words:  heartabnormalities
# not found words:  gmgrain
# not found words:  presenceabsence
# not found words:  gmo—none
# not found words:  seamgate—
# not found words:  cardmehd
# not found words:  doctorkuddles
# not found words:  ahmerkhokharcom
# not found words:  newsfromelsewhere
# not found words:  islinked
# not found words:  germanmade
# not found words:  krgs
# not found words:  ankaras
# not found words:  jmbeck
# not found words:  85year
# not found words:  mapsimage
# not found words:  iammoath—
# not found words:  waleedabunada
# not found words:  pictwittercomz0sqsb4feb—
# not found words:  brennanmancil
# not found words:  pictwittercom7z1hdukunp—
# not found words:  classcnnstorypgraphtxt
# not found words:  cnnstorypgraph3in
# not found words:  appledaily
# not found words:  alsamarai
# not found words:  shirkas
# not found words:  resultspolldaddycom
# not found words:  heartthumpingly
# not found words:  28year
# not found words:  threedecade
# not found words:  year—on
# not found words:  exact—due
# not found words:  and—and
# not found words:  killer—it
# not found words:  big—that
# not found words:  space—and
# not found words:  145°
# not found words:  crusy
# not found words:  syrniki
# not found words:  05pc
# not found words:  volotile
# not found words:  sunnimuslim
# not found words:  pictwittercomukv59saz8u—
# not found words:  baldersdale
# not found words:  pictwittercomukv59saz8u
# not found words:  week—a
# not found words:  dallasbound
# not found words:  arsenal—christmas
# not found words:  newlyelected
# not found words:  nowpresident
# not found words:  antiimmigration
# not found words:  rmass
# not found words:  bordercrossings
# not found words:  casaleargs
# not found words:  casaleargsversion
# not found words:  casaleargsadunits
# not found words:  casaleargscasaleid
# not found words:  159339
# not found words:  mashahead
# not found words:  joshroginbloombergnet
# not found words:  tharshawbloombergnet
# not found words:  italiafacebook
# not found words:  slantyeyed
# not found words:  benedelmanorg
# not found words:  benbenedelmanorg
# not found words:  15yearsold
# not found words:  timpf
# not found words:  280pounder
# not found words:  91footer
# not found words:  weight—one
# not found words:  stilettowearing
# not found words:  stomachturning
# not found words:  children…
# not found words:  heatdetecting
# not found words:  egglike
# not found words:  knightscopes
# not found words:  armedknightscope
# not found words:  relatedunderwater
# not found words:  meltingcbi
# not found words:  jobsrobots
# not found words:  2034people
# not found words:  straighta
# not found words:  antmasturbation
# not found words:  masturbationfree
# not found words:  §§
# not found words:  5424331
# not found words:  2014my
# not found words:  iphone6
# not found words:  hairgate—
# not found words:  bending…but
# not found words:  addrénaline
# not found words:  pérezsantamarina
# not found words:  ​​a
# not found words:  applemakers
# not found words:  brandspankingnew
# not found words:  unit…it
# not found words:  postchristmas
# not found words:  further—there
# not found words:  mysophobic
# not found words:  notsohappy
# not found words:  samsungmade
# not found words:  futuretobemanufactured
# not found words:  smarwatch
# not found words:  bcm4334
# not found words:  juicepower
# not found words:  mid2014
# not found words:  grailwatchcom
# not found words:  ijewelry
# not found words:  multithousanddollar
# not found words:  would…but
# not found words:  gyrometer
# not found words:  batteryhogging
# not found words:  markiyan
# not found words:  appcompany
# not found words:  secondbest
# not found words:  basicness
# not found words:  pslinspired
# not found words:  wait…
# not found words:  maleonly
# not found words:  httptcolasyphtbxl
# not found words:  lahlahlindsey
# not found words:  httptcoycdwfvwtfi
# not found words:  lahlahlindseys
# not found words:  katefagan3
# not found words:  sarahspain
# not found words:  jemelehill
# not found words:  singleissue
# not found words:  10foottall
# not found words:  alharad
# not found words:  ghobari
# not found words:  mukhashaf
# not found words:  sixcontact
# not found words:  smartstraps
# not found words:  newsexplainer
# not found words:  birddefecatesonvladimirputinduringspeechvideo
# not found words:  onedrive
# not found words:  badlyaimed
# not found words:  raqqawi
# not found words:  timesnews
# not found words:  bbcnewscouk
# not found words:  thepurge
# not found words:  httptco0l2sis54hv—
# not found words:  hijanellamarie
# not found words:  httptcoetn60tnxft—
# not found words:  macaranas
# not found words:  jammiepeach
# not found words:  pictwittercomxzg1xaxqdw—
# not found words:  sarangbces
# not found words:  what—
# not found words:  查理
# not found words:  chxrliecutie
# not found words:  httptcogqgeglmelz—
# not found words:  taobby
# not found words:  relatedhalloween
# not found words:  hoaxshah
# not found words:  navyas
# not found words:  fakeebola
# not found words:  mediaeminem
# not found words:  kilometressouth
# not found words:  14thcentury
# not found words:  mackrael
# not found words:  3132234759
# not found words:  katreasesfreep
# not found words:  gurmans
# not found words:  higherres
# not found words:  iraqiprovided
# not found words:  nonvetted
# not found words:  unitsypgin
# not found words:  remotelypiloted
# not found words:  alnujeifi
# not found words:  alraqqawi
# not found words:  alhiyali
# not found words:  livesaving
# not found words:  24022015
# not found words:  amazonss
# not found words:  similarsounding
# not found words:  realisticlooking
# not found words:  gunwielding
# not found words:  weapons—
# not found words:  touchsensitive
# not found words:  techqqcom
# not found words:  03022015
# not found words:  smartphonesavvy
# not found words:  rankboosting
# not found words:  crankboosted
# not found words:  swimmingsanctioned
# not found words:  drinkdriving
# not found words:  140am
# not found words:  bloodalcohol
# not found words:  ashenfaced
# not found words:  worldherald
# not found words:  headtime
# not found words:  manlets
# not found words:  23minutelong
# not found words:  nearidentical
# not found words:  bergdahls
# not found words:  outofcountry
# not found words:  finelytuned
# not found words:  csanady
# not found words:  infantrylike
# not found words:  washingtonbased
# not found words:  buttesilver
# not found words:  clayshooting
# not found words:  lunches—these
# not found words:  welllit
# not found words:  sweetgreens
# not found words:  photo—its
# not found words:  way—to
# not found words:  restaurantquality
# not found words:  elfmonitor
# not found words:  us349—presumably
# not found words:  sport—and
# not found words:  5000citigroup
# not found words:  suvas
# not found words:  baiecomeau
# not found words:  jonun
# not found words:  chiaacu
# not found words:  seinfeldstyle
# not found words:  comedian—the
# not found words:  kid—he
# not found words:  babydangling
# not found words:  jacksonbruno
# not found words:  onionlike
# not found words:  halffilipino
# not found words:  futurewife
# not found words:  neverbefore
# not found words:  fanpopcom
# not found words:  obladoose
# not found words:  moranbong
# not found words:  pittella
# not found words:  weekstallahassee
# not found words:  jsetareh
# not found words:  abinum
# not found words:  japaneselanguage
# not found words:  everreliable

# %%
np.save('embedding_matrix',embedding_matrix)

# %%
embedding_matrix = np.load('embedding_matrix.npy')

# %%
def builtModel(drop_out_rate=0.5,dense_neuron = 64):
    headline_input = Input(shape=(MAX_HEADLINE_LENGTH,), name='headline_input')
    first_body_input = Input(shape=(MAX_BODY_TRUNC,), name='first_body_input')
    last_body_input = Input(shape=(MAX_BODY_TRUNC,), name='last_body_input')
    headline_embedding = Embedding(input_dim=len(tokenizer.word_index)+1,
                          output_dim=EMBEDDING_DIM,
                          weights = [embedding_matrix], trainable=False, name='headline_word_embedding_layer', 
                          mask_zero=True)(headline_input)
    first_body_embedding = Embedding(input_dim=len(tokenizer.word_index)+1,
                          output_dim=EMBEDDING_DIM,
                          weights = [embedding_matrix], trainable=False, name='first_body_word_embedding_layer', 
                          mask_zero=True)(first_body_input)
    last_body_embedding = Embedding(input_dim=len(tokenizer.word_index)+1,
                          output_dim=EMBEDDING_DIM,
                          weights = [embedding_matrix], trainable=False, name='last_bodyword_embedding_layer', 
                          mask_zero=True)(last_body_input)
    encoder_outputs, state_h, state_c = LSTM(LSTM_DIM, return_sequences=False, return_state = True, name='lstm_layer_encoder')(headline_embedding)
    encoder_states = [state_h, state_c]
    first_body_outputs, _, _ = LSTM(LSTM_DIM, return_sequences=False, return_state = True, name='lstm_layer_first_body')(first_body_embedding, initial_state=encoder_states)
    last_body_outputs, _, _ = LSTM(LSTM_DIM, return_sequences=False, return_state = True, name='lstm_layer_last_body')(last_body_embedding, initial_state=encoder_states)
    x = tf.keras.layers.concatenate([first_body_outputs, last_body_outputs])
    x = Dense(dense_neuron, activation='relu')(x)
    x = Dropout(rate=drop_out_rate, name='dropout_1')(x)
    x = Dense(dense_neuron, activation='relu')(x)
    x = Dropout(rate=drop_out_rate, name='dropout_2')(x)

    # And finally we add the main logistic regression layer
    main_output = Dense(4, activation='softmax', name='main_output')(x)
    model = Model(inputs=[headline_input, first_body_input, last_body_input], outputs=main_output)
    model.summary()
    return model

# %%
def trainModel(model,batch=1000,ep=50):
    model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
    output_directory = ''
    model_checkpoint = callbacks.ModelCheckpoint(os.path.join(output_directory , 'weights.{epoch:02d}-{val_loss:.2f}.hdf5'),save_best_only=True,mode='auto',period=10)
    model.fit([train_headline, train_first_body, train_last_body], train_stance_onehot,
          batch_size=batch,
          epochs=ep,
          validation_data=([hold_out_headline, hold_out_first_body, hold_out_last_body], hold_out_stance_onehot),callbacks=[model_checkpoint])
   # model.evaluate(testX, testY)

# %%
trainModel(builtModel())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# headline_input (InputLayer)     (None, 16)           0
# __________________________________________________________________________________________________
# first_body_input (InputLayer)   (None, 50)           0
# __________________________________________________________________________________________________
# headline_word_embedding_layer ( (None, 16, 300)      8362200     headline_input[0][0]
# __________________________________________________________________________________________________
# last_body_input (InputLayer)    (None, 50)           0
# __________________________________________________________________________________________________
# first_body_word_embedding_layer (None, 50, 300)      8362200     first_body_input[0][0]
# __________________________________________________________________________________________________
# lstm_layer_encoder (LSTM)       [(None, 300), (None, 721200      headline_word_embedding_layer[0][
# __________________________________________________________________________________________________
# last_bodyword_embedding_layer ( (None, 50, 300)      8362200     last_body_input[0][0]
# __________________________________________________________________________________________________
# lstm_layer_first_body (LSTM)    [(None, 300), (None, 721200      first_body_word_embedding_layer[0
#                                                                  lstm_layer_encoder[0][1]
#                                                                  lstm_layer_encoder[0][2]
# __________________________________________________________________________________________________
# lstm_layer_last_body (LSTM)     [(None, 300), (None, 721200      last_bodyword_embedding_layer[0][
#                                                                  lstm_layer_encoder[0][1]
#                                                                  lstm_layer_encoder[0][2]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 600)          0           lstm_layer_first_body[0][0]
#                                                                  lstm_layer_last_body[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           38464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           4160        dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 4)            260         dropout_2[0][0]
# ==================================================================================================
# Total params: 27,293,084
# Trainable params: 2,206,484
# Non-trainable params: 25,086,600
# __________________________________________________________________________________________________
# Train on 40350 samples, validate on 9622 samples
# Epoch 1/50
# 40350/40350 [==============================] - 290s 7ms/step - loss: 0.9415 - acc: 0.6856 - val_loss: 0.8195 - val_acc: 0.7169
# Epoch 2/50
# 40350/40350 [==============================] - 289s 7ms/step - loss: 0.7779 - acc: 0.7346 - val_loss: 0.8083 - val_acc: 0.7194
# Epoch 3/50
# 40350/40350 [==============================] - 301s 7ms/step - loss: 0.6611 - acc: 0.7683 - val_loss: 0.8008 - val_acc: 0.7026
# Epoch 4/50
# 40000/40350 [============================>.] - ETA: 2s - loss: 0.5492 - acc: 0.8028
